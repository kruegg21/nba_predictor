# %%
import pyspark as ps    # for the pyspark suite
import warnings         # for displaying warning

try:
    # we try to create a SparkContext to work locally on all cpus available
    sc = ps.SparkContext('local[4]')
    print("Just created a SparkContext")
except ValueError:
    # give a warning if SparkContext already exists (for use inside pyspark)
    warnings.warn("SparkContext already exists in this scope")
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: UserWarning: SparkContext already exists in this scope

# %%
df = spark.read.csv('data/merged_data.csv', header = True)

# %%
df.printSchema()
# Out:
# root
#  |-- 2P: string (nullable = true)
#  |-- 2PA: string (nullable = true)
#  |-- 3P: string (nullable = true)
#  |-- 3PA: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- ChangedTeams: string (nullable = true)
#  |-- Cost: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- FG: string (nullable = true)
#  |-- FGA: string (nullable = true)
#  |-- FT: string (nullable = true)
#  |-- FTA: string (nullable = true)
#  |-- FanDuelScore: string (nullable = true)
#  |-- GS: string (nullable = true)
#  |-- Home: string (nullable = true)
#  |-- Last10AveragePlayerAST: string (nullable = true)
#  |-- Last10AveragePlayerASTPerMinute: string (nullable = true)
#  |-- Last10AveragePlayerBLK: string (nullable = true)
#  |-- Last10AveragePlayerBLKPerMinute: string (nullable = true)
#  |-- Last10AveragePlayerDRB: string (nullable = true)
#  |-- Last10AveragePlayerDRBPerMinute: string (nullable = true)
#  |-- Last10AveragePlayerMP: string (nullable = true)
#  |-- Last10AveragePlayerORB: string (nullable = true)
#  |-- Last10AveragePlayerORBPerMinute: string (nullable = true)
#  |-- Last10AveragePlayerPTS: string (nullable = true)
#  |-- Last10AveragePlayerPTSPerMinute: string (nullable = true)
#  |-- Last10AveragePlayerSTL: string (nullable = true)
#  |-- Last10AveragePlayerSTLPerMinute: string (nullable = true)
#  |-- Last10AveragePlayerTOV: string (nullable = true)
#  |-- Last10AveragePlayerTOVPerMinute: string (nullable = true)
#  |-- Last15AveragePlayerFG%: string (nullable = true)
#  |-- Last20AveragePlayerAST: string (nullable = true)
#  |-- Last20AveragePlayerASTPerMinute: string (nullable = true)
#  |-- Last20AveragePlayerBLK: string (nullable = true)
#  |-- Last20AveragePlayerBLKPerMinute: string (nullable = true)
#  |-- Last20AveragePlayerDRB: string (nullable = true)
#  |-- Last20AveragePlayerDRBPerMinute: string (nullable = true)
#  |-- Last20AveragePlayerFG%: string (nullable = true)
#  |-- Last20AveragePlayerMP: string (nullable = true)
#  |-- Last20AveragePlayerORB: string (nullable = true)
#  |-- Last20AveragePlayerORBPerMinute: string (nullable = true)
#  |-- Last20AveragePlayerPTS: string (nullable = true)
#  |-- Last20AveragePlayerPTSPerMinute: string (nullable = true)
#  |-- Last20AveragePlayerSTL: string (nullable = true)
#  |-- Last20AveragePlayerSTLPerMinute: string (nullable = true)
#  |-- Last20AveragePlayerTOV: string (nullable = true)
#  |-- Last20AveragePlayerTOVPerMinute: string (nullable = true)
#  |-- Last23AveragePlayerAST: string (nullable = true)
#  |-- Last23AveragePlayerASTPerMinute: string (nullable = true)
#  |-- Last23AveragePlayerBLK: string (nullable = true)
#  |-- Last23AveragePlayerBLKPerMinute: string (nullable = true)
#  |-- Last23AveragePlayerDRB: string (nullable = true)
#  |-- Last23AveragePlayerDRBPerMinute: string (nullable = true)
#  |-- Last23AveragePlayerMP: string (nullable = true)
#  |-- Last23AveragePlayerORB: string (nullable = true)
#  |-- Last23AveragePlayerORBPerMinute: string (nullable = true)
#  |-- Last23AveragePlayerPTS: string (nullable = true)
#  |-- Last23AveragePlayerPTSPerMinute: string (nullable = true)
#  |-- Last23AveragePlayerSTL: string (nullable = true)
#  |-- Last23AveragePlayerSTLPerMinute: string (nullable = true)
#  |-- Last23AveragePlayerTOV: string (nullable = true)
#  |-- Last23AveragePlayerTOVPerMinute: string (nullable = true)
#  |-- Last25AveragePlayerAST: string (nullable = true)
#  |-- Last25AveragePlayerASTPerMinute: string (nullable = true)
#  |-- Last25AveragePlayerBLK: string (nullable = true)
#  |-- Last25AveragePlayerBLKPerMinute: string (nullable = true)
#  |-- Last25AveragePlayerDRB: string (nullable = true)
#  |-- Last25AveragePlayerDRBPerMinute: string (nullable = true)
#  |-- Last25AveragePlayerFG%: string (nullable = true)
#  |-- Last25AveragePlayerMP: string (nullable = true)
#  |-- Last25AveragePlayerORB: string (nullable = true)
#  |-- Last25AveragePlayerORBPerMinute: string (nullable = true)
#  |-- Last25AveragePlayerPTS: string (nullable = true)
#  |-- Last25AveragePlayerPTSPerMinute: string (nullable = true)
#  |-- Last25AveragePlayerSTL: string (nullable = true)
#  |-- Last25AveragePlayerSTLPerMinute: string (nullable = true)
#  |-- Last25AveragePlayerTOV: string (nullable = true)
#  |-- Last25AveragePlayerTOVPerMinute: string (nullable = true)
#  |-- Last30AveragePlayerAST: string (nullable = true)
#  |-- Last30AveragePlayerASTPerMinute: string (nullable = true)
#  |-- Last30AveragePlayerBLK: string (nullable = true)
#  |-- Last30AveragePlayerBLKPerMinute: string (nullable = true)
#  |-- Last30AveragePlayerDRB: string (nullable = true)
#  |-- Last30AveragePlayerDRBPerMinute: string (nullable = true)
#  |-- Last30AveragePlayerMP: string (nullable = true)
#  |-- Last30AveragePlayerORB: string (nullable = true)
#  |-- Last30AveragePlayerORBPerMinute: string (nullable = true)
#  |-- Last30AveragePlayerPTS: string (nullable = true)
#  |-- Last30AveragePlayerPTSPerMinute: string (nullable = true)
#  |-- Last30AveragePlayerSTL: string (nullable = true)
#  |-- Last30AveragePlayerSTLPerMinute: string (nullable = true)
#  |-- Last30AveragePlayerTOV: string (nullable = true)
#  |-- Last30AveragePlayerTOVPerMinute: string (nullable = true)
#  |-- Last5AveragePlayerAST: string (nullable = true)
#  |-- Last5AveragePlayerASTPerMinute: string (nullable = true)
#  |-- Last5AveragePlayerBLK: string (nullable = true)
#  |-- Last5AveragePlayerBLKPerMinute: string (nullable = true)
#  |-- Last5AveragePlayerDRB: string (nullable = true)
#  |-- Last5AveragePlayerDRBPerMinute: string (nullable = true)
#  |-- Last5AveragePlayerMP: string (nullable = true)
#  |-- Last5AveragePlayerORB: string (nullable = true)
#  |-- Last5AveragePlayerORBPerMinute: string (nullable = true)
#  |-- Last5AveragePlayerPTS: string (nullable = true)
#  |-- Last5AveragePlayerPTSPerMinute: string (nullable = true)
#  |-- Last5AveragePlayerSTL: string (nullable = true)
#  |-- Last5AveragePlayerSTLPerMinute: string (nullable = true)
#  |-- Last5AveragePlayerTOV: string (nullable = true)
#  |-- Last5AveragePlayerTOVPerMinute: string (nullable = true)
#  |-- New: string (nullable = true)
#  |-- Opp: string (nullable = true)
#  |-- PF: string (nullable = true)
#  |-- Player: string (nullable = true)
#  |-- PlayerAST: string (nullable = true)
#  |-- PlayerASTPerMinute: string (nullable = true)
#  |-- PlayerBLK: string (nullable = true)
#  |-- PlayerBLKPerMinute: string (nullable = true)
#  |-- PlayerDRB: string (nullable = true)
#  |-- PlayerDRBPerMinute: string (nullable = true)
#  |-- PlayerFG%: string (nullable = true)
#  |-- PlayerGameNumber: string (nullable = true)
#  |-- PlayerID: string (nullable = true)
#  |-- PlayerMP: string (nullable = true)
#  |-- PlayerORB: string (nullable = true)
#  |-- PlayerORBPerMinute: string (nullable = true)
#  |-- PlayerPTS: string (nullable = true)
#  |-- PlayerPTSPerMinute: string (nullable = true)
#  |-- PlayerSTL: string (nullable = true)
#  |-- PlayerSTLPerMinute: string (nullable = true)
#  |-- PlayerSeasonGameNumber: string (nullable = true)
#  |-- PlayerTOV: string (nullable = true)
#  |-- PlayerTOVPerMinute: string (nullable = true)
#  |-- Pos: string (nullable = true)
#  |-- Position: string (nullable = true)
#  |-- Prediction: string (nullable = true)
#  |-- Season_x: string (nullable = true)
#  |-- TRB: string (nullable = true)
#  |-- Team: string (nullable = true)
#  |-- Last5AverageTeamPace: string (nullable = true)
#  |-- OppFT%: string (nullable = true)
#  |-- Possessions: string (nullable = true)
#  |-- TeamTRB%: string (nullable = true)
#  |-- Opp3PAr: string (nullable = true)
#  |-- OppFG: string (nullable = true)
#  |-- Last31AverageTeamPace: string (nullable = true)
#  |-- OppPF: string (nullable = true)
#  |-- OppBLK: string (nullable = true)
#  |-- TeamPF: string (nullable = true)
#  |-- TeamSeasonGameNumber: string (nullable = true)
#  |-- OppFT: string (nullable = true)
#  |-- Last10AverageTeamPace: string (nullable = true)
#  |-- OppFTr: string (nullable = true)
#  |-- BackToBackAway: string (nullable = true)
#  |-- TeamORB%: string (nullable = true)
#  |-- TeamTS%: string (nullable = true)
#  |-- OppFTA: string (nullable = true)
#  |-- OppAllowedBLKPerPossession: string (nullable = true)
#  |-- BackToBack: string (nullable = true)
#  |-- TeamFT: string (nullable = true)
#  |-- OppORB: string (nullable = true)
#  |-- Last32AverageTeamPace: string (nullable = true)
#  |-- OppSTL: string (nullable = true)
#  |-- TeamFG: string (nullable = true)
#  |-- TeamAST%: string (nullable = true)
#  |-- EstimatedPace: string (nullable = true)
#  |-- TeamTOV%: string (nullable = true)
#  |-- Won: string (nullable = true)
#  |-- OppORtg: string (nullable = true)
#  |-- Season_y: string (nullable = true)
#  |-- Opp3P: string (nullable = true)
#  |-- Team3PA: string (nullable = true)
#  |-- TeamFT/FGA: string (nullable = true)
#  |-- OppBLK%: string (nullable = true)
#  |-- OppFG%: string (nullable = true)
#  |-- Team3PAr: string (nullable = true)
#  |-- OppORB%: string (nullable = true)
#  |-- OppAllowedORBPerPossession: string (nullable = true)
#  |-- BackToBackHome: string (nullable = true)
#  |-- Team3P%: string (nullable = true)
#  |-- Last35AverageTeamPace: string (nullable = true)
#  |-- OppeFG%: string (nullable = true)
#  |-- OppTRB%: string (nullable = true)
#  |-- OppTOV: string (nullable = true)
#  |-- OppSTL%: string (nullable = true)
#  |-- Last34AverageTeamPace: string (nullable = true)
#  |-- OppFGA: string (nullable = true)
#  |-- Last30AverageTeamPace: string (nullable = true)
#  |-- Result: string (nullable = true)
#  |-- OppTOV%: string (nullable = true)
#  |-- TeamTRB: string (nullable = true)
#  |-- TeamSTL%: string (nullable = true)
#  |-- TeameFG%: string (nullable = true)
#  |-- OppForcedTOVPerPossession: string (nullable = true)
#  |-- TeamMP: string (nullable = true)
#  |-- TeamFTr: string (nullable = true)
#  |-- Last33AverageTeamPace: string (nullable = true)
#  |-- Team2PA: string (nullable = true)
#  |-- TeamBLK%: string (nullable = true)
#  |-- OppAllowedDRBPerPossession: string (nullable = true)
#  |-- OppPTS: string (nullable = true)
#  |-- TeamPace: string (nullable = true)
#  |-- TeamFTA: string (nullable = true)
#  |-- OppAllowedASTPerPossession: string (nullable = true)
#  |-- TeamORtg: string (nullable = true)
#  |-- OppAST%: string (nullable = true)
#  |-- TeamGameNumber: string (nullable = true)
#  |-- TeamFT%: string (nullable = true)
#  |-- Team2P%: string (nullable = true)
#  |-- Opp2P: string (nullable = true)
#  |-- OppAllowedSTLPerPossession: string (nullable = true)
#  |-- Opp2PA: string (nullable = true)
#  |-- Overtime: string (nullable = true)
#  |-- OppTRB: string (nullable = true)
#  |-- OppFT/FGA: string (nullable = true)
#  |-- TeamFGA: string (nullable = true)
#  |-- Opp3PA: string (nullable = true)
#  |-- OppTS%: string (nullable = true)
#  |-- Team2P: string (nullable = true)
#  |-- OppAST: string (nullable = true)
#  |-- OppDRB: string (nullable = true)
#  |-- Team3P: string (nullable = true)
#  |-- TeamFG%: string (nullable = true)
#  |-- Opp3P%: string (nullable = true)
#  |-- Opp2P%: string (nullable = true)
#  |-- OppAllowedAST: string (nullable = true)
#  |-- OppAllowedBLK: string (nullable = true)
#  |-- OppAllowedSTL: string (nullable = true)
#  |-- OppAllowedORB: string (nullable = true)
#  |-- OppForcedTOV: string (nullable = true)
#  |-- OppAllowedPTSPerPossession: string (nullable = true)
#  |-- OppPace: string (nullable = true)
#  |-- OppAllowedPTS: string (nullable = true)
#  |-- OppAllowedDRB: string (nullable = true)
#  |-- Last5AverageOppAllowedAST: string (nullable = true)
#  |-- Last10AverageOppAllowedAST: string (nullable = true)
#  |-- Last20AverageOppAllowedAST: string (nullable = true)
#  |-- Last5AverageOppAllowedBLK: string (nullable = true)
#  |-- Last10AverageOppAllowedBLK: string (nullable = true)
#  |-- Last20AverageOppAllowedBLK: string (nullable = true)
#  |-- Last5AverageOppAllowedSTL: string (nullable = true)
#  |-- Last10AverageOppAllowedSTL: string (nullable = true)
#  |-- Last20AverageOppAllowedSTL: string (nullable = true)
#  |-- Last5AverageOppAllowedORB: string (nullable = true)
#  |-- Last10AverageOppAllowedORB: string (nullable = true)
#  |-- Last20AverageOppAllowedORB: string (nullable = true)
#  |-- Last5AverageOppForcedTOV: string (nullable = true)
#  |-- Last10AverageOppForcedTOV: string (nullable = true)
#  |-- Last20AverageOppForcedTOV: string (nullable = true)
#  |-- Last5AverageOppAllowedPTSPerPossession: string (nullable = true)
#  |-- Last10AverageOppAllowedPTSPerPossession: string (nullable = true)
#  |-- Last20AverageOppAllowedPTSPerPossession: string (nullable = true)
#  |-- Last5AverageOppPace: string (nullable = true)
#  |-- Last10AverageOppPace: string (nullable = true)
#  |-- Last30AverageOppPace: string (nullable = true)
#  |-- Last31AverageOppPace: string (nullable = true)
#  |-- Last32AverageOppPace: string (nullable = true)
#  |-- Last33AverageOppPace: string (nullable = true)
#  |-- Last34AverageOppPace: string (nullable = true)
#  |-- Last35AverageOppPace: string (nullable = true)
#  |-- Last5AverageOppAllowedPTS: string (nullable = true)
#  |-- Last10AverageOppAllowedPTS: string (nullable = true)
#  |-- Last20AverageOppAllowedPTS: string (nullable = true)
#  |-- Last5AverageOppAllowedDRB: string (nullable = true)
#  |-- Last10AverageOppAllowedDRB: string (nullable = true)
#  |-- Last20AverageOppAllowedDRB: string (nullable = true)
#  |-- BucketedMinutes: string (nullable = true)
#  |-- PlayerPossessionsPlayed: string (nullable = true)
#  |-- PlayerASTPerPossession: string (nullable = true)
#  |-- PlayerSTLPerPossession: string (nullable = true)
#  |-- PlayerORBPerPossession: string (nullable = true)
#  |-- PlayerTOVPerPossession: string (nullable = true)
#  |-- PlayerBLKPerPossession: string (nullable = true)
#  |-- PlayerDRBPerPossession: string (nullable = true)
#  |-- PlayerPTSPerPossession: string (nullable = true)
#  |-- Last5AveragePlayerASTPerPossession: string (nullable = true)
#  |-- Last10AveragePlayerASTPerPossession: string (nullable = true)
#  |-- Last20AveragePlayerASTPerPossession: string (nullable = true)
#  |-- Last5AveragePlayerSTLPerPossession: string (nullable = true)
#  |-- Last10AveragePlayerSTLPerPossession: string (nullable = true)
#  |-- Last20AveragePlayerSTLPerPossession: string (nullable = true)
#  |-- Last5AveragePlayerORBPerPossession: string (nullable = true)
#  |-- Last10AveragePlayerORBPerPossession: string (nullable = true)
#  |-- Last20AveragePlayerORBPerPossession: string (nullable = true)
#  |-- Last5AveragePlayerBLKPerPossession: string (nullable = true)
#  |-- Last10AveragePlayerBLKPerPossession: string (nullable = true)
#  |-- Last20AveragePlayerBLKPerPossession: string (nullable = true)
#  |-- Last5AveragePlayerPTSPerPossession: string (nullable = true)
#  |-- Last10AveragePlayerPTSPerPossession: string (nullable = true)
#  |-- Last20AveragePlayerPTSPerPossession: string (nullable = true)
#  |-- Last5AveragePlayerDRBPerPossession: string (nullable = true)
#  |-- Last10AveragePlayerDRBPerPossession: string (nullable = true)
#  |-- Last20AveragePlayerDRBPerPossession: string (nullable = true)
#  |-- Last5AveragePlayerTOVPerPossession: string (nullable = true)
#  |-- Last10AveragePlayerTOVPerPossession: string (nullable = true)
#  |-- Last20AveragePlayerTOVPerPossession: string (nullable = true)
#  |-- EstimatedPlayerPossessions: string (nullable = true)
#  |-- PossessionMinuteAdjustedPlayerAST: string (nullable = true)
#  |-- PossessionMinuteAdjustedPlayerSTL: string (nullable = true)
#  |-- PossessionMinuteAdjustedPlayerORB: string (nullable = true)
#  |-- PossessionMinuteAdjustedPlayerBLK: string (nullable = true)
#  |-- PossessionMinuteAdjustedPlayerPTS: string (nullable = true)
#  |-- PossessionMinuteAdjustedPlayerDRB: string (nullable = true)
#  |-- PossessionMinuteAdjustedPlayerTOV: string (nullable = true)
