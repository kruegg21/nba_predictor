# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import scipy as sp
# %matplotlib inline
df = pd.read_csv('DataSets/FormattedData/formatted_final_data.csv')

# %%
df2 = df[['L20PlayerPTSPerMP','PTS']].replace(-999, np.nan)
df2 = df2[np.isfinite(df2.iloc[:,0])]
print sp.stats.pearsonr(df2.iloc[:,0], df2.iloc[:,1])
plt.scatter(df2.iloc[:,0], df2.iloc[:,1])
plt.xlabel(df2.columns.values[0])
plt.ylabel(df2.columns.values[1])
plt.show()
# Out:
# (0.60303793726735888, 0.0)
