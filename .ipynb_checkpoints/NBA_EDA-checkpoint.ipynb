# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
from test import *
from stat_lists import *
from plotting_functions import *
# %matplotlib inline
df = pd.read_csv('Data/merged_data.csv')
subset = ''
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Subset data 
# 1. Subset data to only players who play 18 or more minutes
df_over17 = df[df['BucketedMinutes'] > 2]
print "Proportion of data points that player 18 or more: ", (float(len(df_over17)) / len(df))
df = df_over17

if 'over17minutes' not in subset:
    subset += 'over17minutes '
# Out:
# Proportion of data points that player 18 or more:  0.683222601913

# %%
# Display plots for all player averages
def player_selection_function(window, key, value):
    x = 'Last' + str(window) + 'Average' + key
    y = key
    return x, y

eda_plotting(df, player_rolling_mean_stat_dict, player_selection_function, subset)
# Out:
# Correlation between Last5AveragePlayerAST and PlayerAST (0.68616790874113076, 0.0)
# Proportion of data points that are NaN:  0.00917025208897
# Correlation between Last10AveragePlayerAST and PlayerAST (0.70329885247313162, 0.0)
# Proportion of data points that are NaN:  0.0192701728812
# Correlation between Last20AveragePlayerAST and PlayerAST (0.70788427809763788, 0.0)
# Proportion of data points that are NaN:  0.0406599904058
# Correlation between Last5AveragePlayerMP and PlayerMP (0.63240294988230339, 0.0)
# Proportion of data points that are NaN:  0.00917025208897
# Correlation between Last10AveragePlayerMP and PlayerMP (0.6284772626053321, 0.0)
# Proportion of data points that are NaN:  0.0192701728812
# Correlation between Last20AveragePlayerMP and PlayerMP (0.61304853705931961, 0.0)
# Proportion of data points that are NaN:  0.0406599904058
# Correlation between Last5AveragePlayerPTS and PlayerPTS (0.59505249480139277, 0.0)
# Proportion of data points that are NaN:  0.00917025208897
# Correlation between Last10AveragePlayerPTS and PlayerPTS (0.61425242595600349, 0.0)
# Proportion of data points that are NaN:  0.0192701728812
# Correlation between Last20AveragePlayerPTS and PlayerPTS (0.61883755263666218, 0.0)
# Proportion of data points that are NaN:  0.0406599904058
# Correlation between Last5AveragePlayerASTPerMinute and PlayerASTPerMinute (0.64243988674174024, 0.0)
# Proportion of data points that are NaN:  0.0133240118551
# Correlation between Last10AveragePlayerASTPerMinute and PlayerASTPerMinute (0.67072392312615703, 0.0)
# Proportion of data points that are NaN:  0.0275553803647
# Correlation between Last20AveragePlayerASTPerMinute and PlayerASTPerMinute (0.68409778737113425, 0.0)
# Proportion of data points that are NaN:  0.0568920059648
# Correlation between Last5AveragePlayerPTSPerMinute and PlayerPTSPerMinute (0.4506921613738612, 0.0)
# Proportion of data points that are NaN:  0.0133240118551
# Correlation between Last10AveragePlayerPTSPerMinute and PlayerPTSPerMinute (0.48973980141277906, 0.0)
# Proportion of data points that are NaN:  0.0275553803647
# Correlation between Last20AveragePlayerPTSPerMinute and PlayerPTSPerMinute (0.50911254561721009, 0.0)
# Proportion of data points that are NaN:  0.0568920059648

# %%
# Display plots for all opponent averages
def opponent_selection_function(window, key, value):
    # Select our x and y values
    y = 'Player' + key[-3:]
    x = 'Last' + str(window) + 'Average' + key
    if len(key) > 14:
        y = 'Player' + key[10:13]
    if key[-4:] == 'Pace':
        y = 'TeamPace'
    return x, y

eda_plotting(df, opponent_rolling_mean_stat_dict, opponent_selection_function, subset)
# Out:
# Correlation between Last5AverageOppAllowedPTS and PlayerPTS (0.046180660545258739, 2.8081558122259249e-126)
# Proportion of data points that are NaN:  0.00474131038663
# Correlation between Last10AverageOppAllowedPTS and PlayerPTS (0.05195459512234063, 1.2978447036917028e-158)
# Proportion of data points that are NaN:  0.00933387378074
# Correlation between Last20AverageOppAllowedPTS and PlayerPTS (0.054090843812294183, 3.4489309293802424e-170)
# Proportion of data points that are NaN:  0.018578499366
# Correlation between Last5AverageOppAllowedPTSPerPossession and PlayerPTS (0.033236282153050176, 2.6995219013792782e-66)
# Proportion of data points that are NaN:  0.00474131038663
# Correlation between Last10AverageOppAllowedPTSPerPossession and PlayerPTS (0.040045710251436148, 5.5245046016542132e-95)
# Proportion of data points that are NaN:  0.00933387378074
# Correlation between Last20AverageOppAllowedPTSPerPossession and PlayerPTS (0.044136968081858019, 6.2483926821898798e-114)
# Proportion of data points that are NaN:  0.018578499366
# Correlation between Last5AverageOppAllowedAST and PlayerAST (0.047398695529339348, 6.2854573925543974e-133)
# Proportion of data points that are NaN:  0.00474131038663
# Correlation between Last10AverageOppAllowedAST and PlayerAST (0.05523584800260789, 4.8051222268586497e-179)
# Proportion of data points that are NaN:  0.00933387378074
# Correlation between Last20AverageOppAllowedAST and PlayerAST (0.059726270314623457, 4.1394561676187261e-207)
# Proportion of data points that are NaN:  0.018578499366
# Correlation between Last5AverageOppPace and TeamPace (0.43612603414284556, 0.0)
# Proportion of data points that are NaN:  0.00474131038663
# Correlation between Last10AverageOppPace and TeamPace (0.46016707086186476, 0.0)
# Proportion of data points that are NaN:  0.00933387378074
# Correlation between Last30AverageOppPace and TeamPace (0.46969637186193369, 0.0)
# Proportion of data points that are NaN:  0.0278974984475
# Correlation between Last31AverageOppPace and TeamPace (0.46967601337160436, 0.0)
# Proportion of data points that are NaN:  0.0288383231752
# Correlation between Last32AverageOppPace and TeamPace (0.46967303906661378, 0.0)
# Proportion of data points that are NaN:  0.029756835854
# Correlation between Last33AverageOppPace and TeamPace (0.46981618921982976, 0.0)
# Proportion of data points that are NaN:  0.0306344431099
# Correlation between Last34AverageOppPace and TeamPace (0.46959714260260171, 0.0)
# Proportion of data points that are NaN:  0.0315641118131
# Correlation between Last35AverageOppPace and TeamPace (0.46913862411033402, 0.0)
# Proportion of data points that are NaN:  0.032501217866

# %%
# Display plots for all team averages
def team_selection_function(window, key, value):
    y = 'Player' + key[-3:]
    x = 'Last' + str(window) + 'Average' + key
    if len(key) > 14:
        y = 'Player' + key[10:13]
    if key[-4:] == 'Pace':
        y = 'TeamPace'
    return x, y
        
eda_plotting(df, team_rolling_mean_stat_dict, team_selection_function, subset)

# %%
# Shows relationship between our linear model prediction for 'EstimatedPace' and the actual pace
x = 'EstimatedPace'
y = 'TeamPace'
scatter_plot_eda(df, x, y, subset)

# %%
# Determines the optimal way to estimate the number of posssessions a player takes part in
print df.columns
for stat in main_stat_list:
    x = 'EstimatedPlayerPossessions'
    y = 'Player' + stat
    scatter_plot_eda(df, x, y, subset)

# %%
# Relationship between possession and minute adjusted stats and actual stats
"""
PossessionMinuteAdjustedPlayerStat =
(Stat / (TeamPossessions * (PlayerMP/TeamMP)) * (EstimatedMinutes / 48) * (EstimatedPossessions)
"""
for key, value in player_post_merge_rolling_mean_stat_dict.iteritems():
    for window in value:
        df['Last' + str(window) + 'Average' + key] = df['Last' + str(window) + 'Average' + key] * df.EstimatedPlayerPossessions
        x = 'Last' + str(window) + 'Average' + key
        y = 'Player' + key[6:9]
        scatter_plot_eda(df, x, y, subset)
# Out:
# Index([u'2P', u'2PA', u'3P', u'3PA', u'Age', u'BLK', u'ChangedTeams', u'DRB',
#        u'Date', u'FG',
#        ...
#        u'PlayerPossessionsPlayed', u'PlayerPTSPerPossession',
#        u'PlayerASTPerPossession', u'Last5AveragePlayerASTPerPossession',
#        u'Last10AveragePlayerASTPerPossession',
#        u'Last20AveragePlayerASTPerPossession',
#        u'Last5AveragePlayerPTSPerPossession',
#        u'Last10AveragePlayerPTSPerPossession',
#        u'Last20AveragePlayerPTSPerPossession', u'EstimatedPlayerPossessions'],
#       dtype='object', length=240)
# Correlation between Last5AveragePlayerASTPerPossession and PlayerAST (0.71207245659962115, 0.0)
# Proportion of data points that are NaN:  0.046881333368
# Correlation between Last10AveragePlayerASTPerPossession and PlayerAST (0.73465781079952652, 0.0)
# Proportion of data points that are NaN:  0.0568325071677
# Correlation between Last20AveragePlayerASTPerPossession and PlayerAST (0.74427544260349954, 0.0)
# Proportion of data points that are NaN:  0.0776868355193
# Correlation between Last5AveragePlayerPTSPerPossession and PlayerPTS (0.68072035307833534, 0.0)
# Proportion of data points that are NaN:  0.046881333368
# Correlation between Last10AveragePlayerPTSPerPossession and PlayerPTS (0.7070583298621187, 0.0)
# Proportion of data points that are NaN:  0.0568325071677
# Correlation between Last20AveragePlayerPTSPerPossession and PlayerPTS (0.71855292971585905, 0.0)
# Proportion of data points that are NaN:  0.0776868355193
